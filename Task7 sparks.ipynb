# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer
import string
from nltk.corpus import stopwords
df = pd.read_csv(r'C:\Users\Ahmed\Downloads\india-news-headlines.csv')

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\ahmed\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.9.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: urllib3 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: joblib>=0.11 in c:\users\ahmed\anaconda3\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ahmed\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahmed\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ahmed\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ahmed\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\ahmed\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ahmed\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in c:\users\ahmed\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\ahmed\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\ahmed\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ahmed\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\ahmed\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in c:\users\ahmed\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\ahmed\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: colorama in c:\users\ahmed\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head(n=50)
# Out:
#     publish_date headline_category  \
# 0       20010102           unknown
# 1       20010102           unknown
# 2       20010102           unknown
# 3       20010102           unknown
# 4       20010102           unknown
# 5       20010102           unknown
# 6       20010102           unknown
# 7       20010102           unknown
# 8       20010102           unknown
# 9       20010102           unknown
# 10      20010102           unknown
# 11      20010102           unknown
# 12      20010102           unknown
# 13      20010102           unknown
# 14      20010102           unknown
# 15      20010102           unknown
# 16      20010102           unknown
# 17      20010102           unknown
# 18      20010102           unknown
# 19      20010102           unknown
# 20      20010102           unknown
# 21      20010102           unknown
# 22      20010102           unknown
# 23      20010102           unknown
# 24      20010102           unknown
# 25      20010102           unknown
# 26      20010102           unknown
# 27      20010102           unknown
# 28      20010102           unknown
# 29      20010102           unknown
# 30      20010102           unknown
# 31      20010102           unknown
# 32      20010102           unknown
# 33      20010102           unknown
# 34      20010102           unknown
# 35      20010102           unknown
# 36      20010102           unknown
# 37      20010102           unknown
# 38      20010102           unknown
# 39      20010102           unknown
# 40      20010102           unknown
# 41      20010102           unknown
# 42      20010102           unknown
# 43      20010102           unknown
# 44      20010102           unknown
# 45      20010102           unknown
# 46      20010102           unknown
# 47      20010102           unknown
# 48      20010102           unknown
# 49      20010102           unknown
#
#                                         headline_text
# 0   Status quo will not be disturbed at Ayodhya; s...
# 1                 Fissures in Hurriyat over Pak visit
# 2               America's unwanted heading for India?
# 3                  For bigwigs; it is destination Goa
# 4                Extra buses to clear tourist traffic
# 5         Dilute the power of transfers; says Riberio
# 6                   Focus shifts to teaching of Hindi
# 7                IT will become compulsory in schools
# 8       Move to stop freedom fighters' pension flayed
# 9   Gilani claims he applied for passport 2 years ago
# 10                     Parivar dismisses PM's warning
# 11              India; Pak exchange lists of N-plants
# 12        Will Qureshi's return really help the govt?
# 13         PM's tacit message: Put Ram tample on hold
# 14               Text of the Prime Minister's article
# 15             NCW to focus on violence against women
# 16               BBC's reality TV will focus on AIIMS
# 17                      Jaitley firm on legal reforms
# 18              Hoshangabad farmers have enough water
# 19         BJP jumps into rail track conversion issue
# 20              America's unwanted heading for India?
# 21            State may take AP to court over Krishna
# 22                  This official has sued the briber
# 23      Park turns temple compound as residents watch
# 24       Moves afoot to evict squatters in Urban dist
# 25           Mafia calls the shots in Gandhinagar too
# 26  Status quo will not be disturbed at Ayodhya; s...
# 27                Fissures in Hurriyat over Pak visit
# 28              America's unwanted heading for India?
# 29                 For bigwigs; it is destination Goa
# 30               Extra buses to clear tourist traffic
# 31        Dilute the power of transfers; says Riberio
# 32                  Focus shifts to teaching of Hindi
# 33               IT will become compulsory in schools
# 34      Move to stop freedom fighters' pension flayed
# 35  Gilani claims he applied for passport 2 years ago
# 36                     Parivar dismisses PM's warning
# 37              India; Pak exchange lists of N-plants
# 38        Will Qureshi's return really help the govt?
# 39         PM's tacit message: Put Ram tample on hold
# 40               Text of the Prime Minister's article
# 41             NCW to focus on violence against women
# 42               BBC's reality TV will focus on AIIMS
# 43                      Jaitley firm on legal reforms
# 44              Hoshangabad farmers have enough water
# 45         BJP jumps into rail track conversion issue
# 46              America's unwanted heading for India?
# 47            State may take AP to court over Krishna
# 48                  This official has sued the briber
# 49      Park turns temple compound as residents watch

# %%
from datetime import datetime
df["publish_date"] = pd.to_datetime(df["publish_date"], format='%Y%m%d')

# %%
def analyze_polarity(headline):
    result = TextBlob(headline)
    if result.sentiment.polarity > 0:
        return 1
    elif result.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
df['Result'] = np.array([analyze_polarity(headline) for headline in df['headline_text']])

# %%
ositive_headlines = [ head for index, head in enumerate(df['headline_text']) if df['Result'][index] > 0]
unbiased_headlines = [ head for index, head in enumerate(df['headline_text']) if df['Result'][index] == 0]
negative_headlines = [ head for index, head in enumerate(df['headline_text']) if df['Result'][index] < 0]

# %%
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(df['headline_text'].values,df['Result'].values,test_size=0.2)
re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
def tokenize(s): return re_tok.sub(r' \1 ',s).split()
vect = CountVectorizer(tokenizer=tokenize)
tf_train = vect.fit_transform(X_train)
tf_test = vect.transform(X_test)

# %%
def label_plot(x, y, title):
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
data_cities = df[df['headline_category'].str.contains('^city\.[a-z]+$', regex=True)]
data_cities['city_name'] = data_cities.headline_category.str[5:]
city_list = data_cities['city_name'].unique().tolist()
#Bar chart of covrage by cities in descending order
grp_city = data_cities.groupby(['city_name'])['headline_text'].count().nlargest(20)
ts = pd.Series(grp_city)
ts.plot(kind='bar', figsize=(14,13))
label_plot('City Name', 'Number of recorded articles', 'Number of articles per city')
plt.show()
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_19312\3934921356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cities['city_name'] = data_cities.headline_category.str[5:]

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost= AdaBoostClassifier(n_estimators=150)
adaboost.fit(tf_train,Y_train)
pred=adaboost.predict(tf_test)
accuracy=(pred == Y_test).mean()
print(accuracy)
print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
# Out:
# 0.9229862201004116
# [[ 65832  19379   3198]
#  [  1522 502550   2630]
#  [  2950  26556 105577]]
#               precision    recall  f1-score   support
#
#           -1       0.94      0.74      0.83     88409
#            0       0.92      0.99      0.95    506702
#            1       0.95      0.78      0.86    135083
#
#     accuracy                           0.92    730194
#    macro avg       0.93      0.84      0.88    730194
# weighted avg       0.92      0.92      0.92    730194

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(Y_test, pred), square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
# Out:
# <AxesSubplot:>
